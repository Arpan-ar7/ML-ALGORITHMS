# %% [markdown]
# Fundamental Forms of Linear Regression
# 1. SIMPLE LR
# 2. MULTIPLE LR
# 3. POLYNOMIAL LR
#
#
# There are many more regression algo even fro classification algo but for now we will learn these three then as we move forward we will unlock on by one hope so

# %%
# Building our own simple lr model from scratch 
import pandas as pd 
import numpy as np

# %%
class LinearLR:
    def __init__(self):
        self.m=None
        self.b=None

    def fit(self,X_train,y_train):
        X_train = X_train.values.flatten()
        y_train = y_train.values
        
        num=0
        den=0
        for i in range(X_train.shape[0]):
            num=num+((X_train[i]-X_train.mean())*(y_train[i]- y_train.mean()))
            den=den+((X_train[i]-X_train.mean())*(X_train[i]-X_train.mean()))
        self.m=num/den

        self.b=(y_train.mean()-self.m *X_train.mean())
        print(self.m)
        print(self.b)

    def predict(self,X_test):
        X_test = np.array(X_test).flatten()
        return self.m *X_test+self.b

# %%
import pandas as pd

data = {
    "CGPA": [
        5.5, 5.8, 6.0, 6.2, 6.4,
        6.5, 6.7, 6.8, 7.0, 7.1,
        7.2, 7.3, 7.5, 7.6, 7.8,
        8.0, 8.1, 8.3, 8.5, 8.7
    ],
    
    "Package_LPA": [
        2.5, 2.7, 2.8, 3.0, 3.1,
        3.2, 3.4, 3.5, 3.7, 3.8,
        4.0, 4.1, 4.4, 4.6, 4.9,
        5.2, 5.5, 5.9, 6.3, 6.8
    ]
}

df = pd.DataFrame(data)

print(df)
# Out:
#     CGPA  Package_LPA
# 0    5.5          2.5
# 1    5.8          2.7
# 2    6.0          2.8
# 3    6.2          3.0
# 4    6.4          3.1
# 5    6.5          3.2
# 6    6.7          3.4
# 7    6.8          3.5
# 8    7.0          3.7
# 9    7.1          3.8
# 10   7.2          4.0
# 11   7.3          4.1
# 12   7.5          4.4
# 13   7.6          4.6
# 14   7.8          4.9
# 15   8.0          5.2
# 16   8.1          5.5
# 17   8.3          5.9
# 18   8.5          6.3
# 19   8.7          6.8

# %%
X=df.drop('Package_LPA',axis=1)
y=df['Package_LPA']

# %%
X_test
# Out:
#     CGPA
# 12   7.5
# 4    6.4
# 18   8.5
# 0    5.5

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)

# %%
X_train.shape
# Out:
# (16, 1)

# %%
lr=LinearLR()
lr.fit(X_train,y_train)
# Out:
# 1.3725887736778077
# -5.680310490644729

# %%
lr.predict([[9.0]])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 lr.predict([[9.0]])
#
# Cell In[54], line 22, in LinearLR.predict(self, X_test)
#      21     def predict(self,X_test):
# ---> 22         X_test = np.array(X_test).flatten()
#      23         return self.m *X_test+self.b
#
# NameError: name 'np' is not defined

# %%
from sklearn.linear_model import LinearRegression
lr1=LinearRegression()
lr1.fit(X_train,y_train)
lr1.predict([[9.0]])
# Out:
# d:\DS\ML\ML ALGOS\.venv\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([6.67298847])

# %%
import matplotlib.pyplot as plt

# Actual data
plt.scatter(X_train, y_train, label="Actual Data")

# Regression line
y_pred = lr.predict(X_train)
plt.plot(X_train, y_pred, label="Regression Line")

plt.xlabel("CGPA")
plt.ylabel("Package (LPA)")
plt.title("CGPA vs Package")
plt.legend()

plt.show()

# %%
import matplotlib.pyplot as plt

# Actual data
plt.scatter(X_train, y_train, label="Actual Data")

# Regression line
y_pred = lr1.predict(X_train)
plt.plot(X_train, y_pred, label="Regression Line")

plt.xlabel("CGPA")
plt.ylabel("Package (LPA)")
plt.title("CGPA vs Package")
plt.legend()

plt.show()

# %%
import matplotlib.pyplot as plt

y_pred = lr.predict(X_test)

plt.scatter(X_test, y_test, label="Actual")
plt.plot(X_test, y_pred, label="Predicted")

plt.xlabel("CGPA")
plt.ylabel("Package (LPA)")
plt.title("Linear Regression: CGPA vs Package")
plt.legend()

plt.show()
